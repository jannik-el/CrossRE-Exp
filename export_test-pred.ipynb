# %%
import pandas as pd
import os

# %%
def find_all_files(root_folder, output_folder):
    file_ending = "combined-test-pred.csv"

    # find all files named "combined-test-pred.csv" in the root folder
    files = []
    for root, dirs, files in os.walk(root_folder):
        for file in files:
            if file.endswith(file_ending):
                print(root.split("/"))

                files.append(os.path.join(root, file))

                # copy file to the output folder

# %%
find_all_files("DomainDatasetEmbedCrossRE")
# Out:
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ['DomainDatasetEmbedCrossRE', 'results_combined', 'rs4012']
# ...
